# %%
import datetime

# %%
datetime_str = '2026-08-30 18:28:56'

# %%
format = '%Y-%m-%d %H:%M:%S' 
datetime_dt = datetime.datetime.strptime(datetime_str, format)
print(datetime_dt)
# Out:
# 2026-08-30 18:28:56

# %%
print(type(datetime_dt))
# Out:
# <class 'datetime.datetime'>

# %%
datetime_str = datetime_dt.strftime('%Y-%m-%d %H:%M:%S')

print(type(datetime_str)) # <class 'str'>
print(datetime_str)       # 2018-08-24 18:00:25
# Out:
# <class 'str'>
# 2026-08-30 18:28:56

# %%
datetime_str = datetime_dt.strftime('%Y-%m-%d %H')

print(type(datetime_str)) # <class 'str'>
print(datetime_str)       # 2018-08-24 18:00:25
# Out:
# <class 'str'>
# 2026-08-30 18

# %%
datetime_str = datetime_dt.strftime('%Y-%m')

print(type(datetime_str)) # <class 'str'>
print(datetime_str)       # 2018-08-24 18:00:25
# Out:
# <class 'str'>
# 2026-08

# %%
import numpy as np
np.datetime64('2019-01-01')
# Out:
# np.datetime64('2019-01-01')

# %%
np.datetime64(1000,'ns')
# Out:
# np.datetime64('1970-01-01T00:00:00.000001000')

# %%
np.datetime64(10000000000,'ns')
# Out:
# np.datetime64('1970-01-01T00:00:10.000000000')

# %%
np.datetime64(1000000000,'s')
# Out:
# np.datetime64('2001-09-09T01:46:40')

# %%
np.datetime64(10000,'D')
# Out:
# np.datetime64('1997-05-19')

# %%
np.array(['2007-07-13', '2006-01-13', '2010-08-13'], dtype='datetime64')
# Out:
# array(['2007-07-13', '2006-01-13', '2010-08-13'], dtype='datetime64[D]')

# %%
# 달단위
np.array(['2007-07-13', '2006-01-13', '2010-08-13'], dtype='datetime64[M]')
# Out:
# array(['2007-07', '2006-01', '2010-08'], dtype='datetime64[M]')

# %%
# 달단위
np.arange('2005-02', '2006-03', dtype='datetime64[M]')
# Out:
# array(['2005-02', '2005-03', '2005-04', '2005-05', '2005-06', '2005-07',
#        '2005-08', '2005-09', '2005-10', '2005-11', '2005-12', '2006-01',
#        '2006-02'], dtype='datetime64[M]')

# %%
# 주단위
np.arange('2005-02', '2006-03', dtype='datetime64[W]')
# Out:
# array(['2005-01-27', '2005-02-03', '2005-02-10', '2005-02-17',
#        '2005-02-24', '2005-03-03', '2005-03-10', '2005-03-17',
#        '2005-03-24', '2005-03-31', '2005-04-07', '2005-04-14',
#        '2005-04-21', '2005-04-28', '2005-05-05', '2005-05-12',
#        '2005-05-19', '2005-05-26', '2005-06-02', '2005-06-09',
#        '2005-06-16', '2005-06-23', '2005-06-30', '2005-07-07',
#        '2005-07-14', '2005-07-21', '2005-07-28', '2005-08-04',
#        '2005-08-11', '2005-08-18', '2005-08-25', '2005-09-01',
#        '2005-09-08', '2005-09-15', '2005-09-22', '2005-09-29',
#        '2005-10-06', '2005-10-13', '2005-10-20', '2005-10-27',
#        '2005-11-03', '2005-11-10', '2005-11-17', '2005-11-24',
#        '2005-12-01', '2005-12-08', '2005-12-15', '2005-12-22',
#        '2005-12-29', '2006-01-05', '2006-01-12', '2006-01-19',
#        '2006-01-26', '2006-02-02', '2006-02-09', '2006-02-16'],
#       dtype='datetime64[W]')

# %%
# 주단위
np.arange('2005-02', '2006-03', dtype='datetime64[W]')
# Out:
# array(['2005-01-27', '2005-02-03', '2005-02-10', '2005-02-17',
#        '2005-02-24', '2005-03-03', '2005-03-10', '2005-03-17',
#        '2005-03-24', '2005-03-31', '2005-04-07', '2005-04-14',
#        '2005-04-21', '2005-04-28', '2005-05-05', '2005-05-12',
#        '2005-05-19', '2005-05-26', '2005-06-02', '2005-06-09',
#        '2005-06-16', '2005-06-23', '2005-06-30', '2005-07-07',
#        '2005-07-14', '2005-07-21', '2005-07-28', '2005-08-04',
#        '2005-08-11', '2005-08-18', '2005-08-25', '2005-09-01',
#        '2005-09-08', '2005-09-15', '2005-09-22', '2005-09-29',
#        '2005-10-06', '2005-10-13', '2005-10-20', '2005-10-27',
#        '2005-11-03', '2005-11-10', '2005-11-17', '2005-11-24',
#        '2005-12-01', '2005-12-08', '2005-12-15', '2005-12-22',
#        '2005-12-29', '2006-01-05', '2006-01-12', '2006-01-19',
#        '2006-01-26', '2006-02-02', '2006-02-09', '2006-02-16'],
#       dtype='datetime64[W]')

# %%
# 일단위
np.arange('2005-02', '2005-03', dtype='datetime64[D]')
# Out:
# array(['2005-02-01', '2005-02-02', '2005-02-03', '2005-02-04',
#        '2005-02-05', '2005-02-06', '2005-02-07', '2005-02-08',
#        '2005-02-09', '2005-02-10', '2005-02-11', '2005-02-12',
#        '2005-02-13', '2005-02-14', '2005-02-15', '2005-02-16',
#        '2005-02-17', '2005-02-18', '2005-02-19', '2005-02-20',
#        '2005-02-21', '2005-02-22', '2005-02-23', '2005-02-24',
#        '2005-02-25', '2005-02-26', '2005-02-27', '2005-02-28'],
#       dtype='datetime64[D]')

# %%
# 시간단위
np.arange('2005-02-01', '2005-02-02', dtype='datetime64[h]')
# Out:
# array(['2005-02-01T00', '2005-02-01T01', '2005-02-01T02', '2005-02-01T03',
#        '2005-02-01T04', '2005-02-01T05', '2005-02-01T06', '2005-02-01T07',
#        '2005-02-01T08', '2005-02-01T09', '2005-02-01T10', '2005-02-01T11',
#        '2005-02-01T12', '2005-02-01T13', '2005-02-01T14', '2005-02-01T15',
#        '2005-02-01T16', '2005-02-01T17', '2005-02-01T18', '2005-02-01T19',
#        '2005-02-01T20', '2005-02-01T21', '2005-02-01T22', '2005-02-01T23'],
#       dtype='datetime64[h]')

# %%
np.datetime64('2009-01-01') - np.datetime64('2008-01')
# Out:
# np.timedelta64(366,'D')

# %%
np.datetime64('2009-01-01') - np.datetime64('2008-01-01')
# Out:
# np.timedelta64(366,'D')

# %%
import pandas as pd

# %%
pd.Timestamp(1239.1238934)
# Out:
# Timestamp('1970-01-01 00:00:00.000001239')

# %%
pd.Timestamp(1239.1238934, unit='D')
# Out:
# Timestamp('1973-05-24 02:58:24.389760')

# %%
pd.Timestamp('2019-1-1')
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
pd.to_datetime('2019-1-1 12')
# Out:
# Timestamp('2019-01-01 12:00:00')

# %%
pd.to_datetime(['2018-1-1', '2019-1-2'])
# Out:
# DatetimeIndex(['2018-01-01', '2019-01-02'], dtype='datetime64[us]', freq=None)

# %%
pd.date_range('2019-01','2019-02')
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12',
#                '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-16',
#                '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20',
#                '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24',
#                '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28',
#                '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01'],
#               dtype='datetime64[us]', freq='D')

# %%
pd.Period('2019-01')
# Out:
# Period('2019-01', 'M')

# %%
pd.Period('2019-05', freq='D')
# Out:
# Period('2019-05-01', 'D')

# %%
pd.period_range('2019-01','2019-02',freq='D')
# Out:
# PeriodIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#              '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#              '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12',
#              '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-16',
#              '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20',
#              '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24',
#              '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28',
#              '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01'],
#             dtype='period[D]')

# %%
p = pd.Period('2019-06-13')
test = pd.Timestamp('2019-06-13 22:11')
p.start_time < test < p.end_time
# Out:
# True

# %%
p.start_time
# Out:
# Timestamp('2019-06-13 00:00:00')

# %%
p.end_time
# Out:
# Timestamp('2019-06-13 23:59:59.999999')

# %%
import FinanceDataReader as fdr

# %%
df_krs = fdr.StockListing('KRX')

# %%
type(df_krx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 type(df_krx)
#
# NameError: name 'df_krx' is not defined

# %%
pip install -U finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in C:\Anaconda\envs\tf_env\Lib\site-packages (0.9.202)
# Requirement already satisfied: beautifulsoup4 in C:\Anaconda\envs\tf_env\Lib\site-packages (from finance-datareader) (4.15.0)
# Requirement already satisfied: lxml in C:\Anaconda\envs\tf_env\Lib\site-packages (from finance-datareader) (6.1.2)
# Requirement already satisfied: pandas>=1.1.0 in C:\Anaconda\envs\tf_env\Lib\site-packages (from finance-datareader) (3.0.5)
# Requirement already satisfied: plotly in C:\Anaconda\envs\tf_env\Lib\site-packages (from finance-datareader) (7.0.0)
# Requirement already satisfied: requests-file in C:\Anaconda\envs\tf_env\Lib\site-packages (from finance-datareader) (3.0.1)
# Requirement already satisfied: requests>=2.3.0 in C:\Anaconda\envs\tf_env\Lib\site-packages (from finance-datareader) (2.34.2)
# Requirement already satisfied: tabulate>=0.9.0 in C:\Anaconda\envs\tf_env\Lib\site-packages (from finance-datareader) (0.10.0)
# Requirement already satisfied: tqdm in C:\Anaconda\envs\tf_env\Lib\site-packages (from finance-datareader) (4.70.0)
# Requirement already satisfied: numpy>=1.26.0 in C:\Anaconda\envs\tf_env\Lib\site-packages (from pandas>=1.1.0->finance-datareader) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Anaconda\envs\tf_env\Lib\site-packages (from pandas>=1.1.0->finance-datareader) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Anaconda\envs\tf_env\Lib\site-packages (from pandas>=1.1.0->finance-datareader) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Anaconda\envs\tf_env\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->finance-datareader) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Anaconda\envs\tf_env\Lib\site-packages (from requests>=2.3.0->finance-datareader) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in C:\Anaconda\envs\tf_env\Lib\site-packages (from requests>=2.3.0->finance-datareader) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Anaconda\envs\tf_env\Lib\site-packages (from requests>=2.3.0->finance-datareader) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Anaconda\envs\tf_env\Lib\site-packages (from requests>=2.3.0->finance-datareader) (2026.7.22)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Anaconda\envs\tf_env\Lib\site-packages (from beautifulsoup4->finance-datareader) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Anaconda\envs\tf_env\Lib\site-packages (from beautifulsoup4->finance-datareader) (4.16.0)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Anaconda\envs\tf_env\Lib\site-packages (from plotly->finance-datareader) (2.25.0)
# Requirement already satisfied: packaging in C:\Anaconda\envs\tf_env\Lib\site-packages (from plotly->finance-datareader) (26.3)
# Requirement already satisfied: colorama in C:\Anaconda\envs\tf_env\Lib\site-packages (from tqdm->finance-datareader) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import FinanceDataReader as fdr

# %%
df_krx = fdr.StockListing('KRX')

# %%
type(df_krx)
# Out:
# pandas.DataFrame

# %%
df_krx
# Out:
#         Code        ISU_CD     Name  Market   Dept    Close ChangeCode  \
# 0     005930  KR7005930003     삼성전자   KOSPI    NaN   257000          2
# 1     000660  KR7000660001   SK하이닉스   KOSPI    NaN  1653000          2
# 2     005935  KR7005931001    삼성전자우   KOSPI    NaN   186800          2
# 3     402340  KR7402340004    SK스퀘어   KOSPI    NaN  1028000          2
# 4     009150  KR7009150004     삼성전기   KOSPI    NaN  1421000          1
# ...      ...           ...      ...     ...    ...      ...        ...
# 2870  004415  KR7004411005    서울식품우   KOSPI    NaN     5470          1
# 2871  002785  KR7002781003   진흥기업우B   KOSPI    NaN     1336          0
# 2872  279060  KR7279060008     이노벡스   KONEX  일반기업부      115          0
# 2873  002787  KR7002782001  진흥기업2우B   KOSPI    NaN     2895          0
# 2874  032685  KR7032681009    소프트센우  KOSDAQ  중견기업부     9180          1
#
#       Changes  ChagesRatio     Open     High      Low    Volume  \
# 0       -9000        -3.38   262500   266000   256000  15106746
# 1      -77000        -4.45  1704000  1725000  1653000   3455018
# 2       -7500        -3.86   189800   192500   186200   3246546
# 3      -40000        -3.75  1063000  1075000  1026000    439255
# 4       36000         2.60  1398000  1460000  1393000    800641
# ...       ...          ...      ...      ...      ...       ...
# 2870      100         1.86     5370     5470     5370       630
# 2871        0         0.00        0        0        0         0
# 2872        0         0.00        0        0        0         0
# 2873        0         0.00        0        0        0         0
# 2874      280         3.15     9100     9500     9100      2412
#
#              Amount            Marcap      Stocks MarketId
# 0     3925852660500  1502493602256000  5846278608      STK
# 1     5851249603291  1207503879345000   730492365      STK
# 2      611432364650   149882940720400   802371203      STK
# 3      459757402000   135617869944000   131923998      STK
# 4     1145352643080   106139742016000    74693696      STK
# ...             ...               ...         ...      ...
# 2870        3408340        1216801500      222450      STK
# 2871              0        1145243248      857218      STK
# 2872              0        1127904590     9807866      KNX
# 2873              0         853469160      294808      STK
# 2874       22396780         655103160       71362      KSQ
#
# [2875 rows x 17 columns]

# %%
df_spx = fdr.StockListing('S&P500')

# %%
df_spx.head()
# Out:
#   Symbol                 Name                  Sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV               AbbVie             Health Care
# 4    ACN            Accenture  Information Technology
#
#                          Industry
# 0        Industrial Conglomerates
# 1               Building Products
# 2           Health Care Equipment
# 3                   Biotechnology
# 4  IT Consulting & Other Services

# %%
print('s&p 종목 데이터프레임의 크기 :', len(df_spx))
# Out:
# s&p 종목 데이터프레임의 크기 : 503

# %%
df = fdr.DataReader('000660', '2025')

# %%
df.head(10)
# Out:
#               Open    High     Low   Close   Volume    Change
# Date
# 2025-01-02  170500  172200  170000  171200  2102175 -0.015526
# 2025-01-03  174500  182700  173100  181900  4233446  0.062500
# 2025-01-06  184400  199800  184400  199800  7320382  0.098406
# 2025-01-07  205000  206500  194800  195000  6075445 -0.024024
# 2025-01-08  193100  198100  191000  194700  4275792 -0.001538
# 2025-01-09  201000  206000  199800  205000  6692254  0.052902
# 2025-01-10  208000  212500  202500  203500  6149475 -0.007317
# 2025-01-13  203000  203000  193900  194300  4767294 -0.045209
# 2025-01-14  194300  197900  193600  195000  3019149  0.003603
# 2025-01-15  198000  201000  197700  198200  3620460  0.016410

# %%
df = fdr.DataReader('000660', '2026')

# %%
df.head(10)
# Out:
#               Open    High     Low   Close   Volume    Change
# Date
# 2026-01-02  651000  679000  647000  677000  4181895  0.039939
# 2026-01-05  698000  700000  684000  696000  4337511  0.028065
# 2026-01-06  690000  727000  671000  726000  4830275  0.043103
# 2026-01-07  760000  762000  728000  742000  5693115  0.022039
# 2026-01-08  731000  788000  731000  756000  6496379  0.018868
# 2026-01-09  744000  756000  727000  744000  4343703 -0.015873
# 2026-01-12  755000  762000  735000  749000  3329793  0.006720
# 2026-01-13  753000  754000  724000  738000  3771944 -0.014686
# 2026-01-14  733000  750000  728000  742000  4885051  0.005420
# 2026-01-15  732000  750000  727000  749000  3003414  0.009434

# %%
# 애플(AAPL), 2017년
df = fdr.DataReader('AAPL', '2017')
df.head(10)
# Out:
#                  Open       High        Low      Close     Volume  Adj Close
#                     Open          High           Low         Close  \
# 2015-12-31  500999.34375  508677.84375  492009.40625  505911.90625
# 2016-01-01  506092.87500  512567.25000  502287.40625  510103.59375
# 2016-01-02  510441.81250  512133.03125  507209.71875  509051.25000
# 2016-01-03  509215.68750  509409.46875  498978.56250  505155.40625
# 2016-01-04  505214.15625  517275.09375  505932.96875  514646.37500
#
#                   Volume     Adj Close
# 2015-12-31  5.404555e+10  505911.90625
# 2016-01-01  4.260775e+10  510103.59375
# 2016-01-02  3.534695e+10  509051.25000
# 2016-01-03  4.655981e+10  505155.40625
# 2016-01-04  4.572320e+10  514646.37500

# %%
## Quiz 1

# %%
import datetime
datetime_str = '07-08-2021"
# Out:
#   Cell In[22], line 2
#     datetime_str = '07-08-2021"
#                    ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
import datetime

# %%
datetime_str = '07-08-2021'

# %%
format = '%d-%m-%y'
datetime_dt = datetime.datetime.striptime(datetime_srt, format)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 format = '%d-%m-%y'
# ----> 2 datetime_dt = datetime.datetime.striptime(datetime_srt, format)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'striptime'

# %%
format = '%d-%m-%y'
datetime_dt = datetime.datetime.strptime(datetime_srt, format)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 format = '%d-%m-%y'
# ----> 2 datetime_dt = datetime.datetime.strptime(datetime_srt, format)
#
# NameError: name 'datetime_srt' is not defined

# %%
format = '%d-%m-%y'
datetime_dt = datetime.datetime.striptime(datetime_str, format)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 format = '%d-%m-%y'
# ----> 2 datetime_dt = datetime.datetime.striptime(datetime_str, format)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'striptime'

# %%
format = '%d-%m-%y'
datetime_dt = datetime.datetime.strptime(datetime_str, format)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 format = '%d-%m-%y'
# ----> 2 datetime_dt = datetime.datetime.strptime(datetime_str, format)
#
# File C:\Anaconda\envs\tf_env\Lib\_strptime.py:653, in _strptime_datetime(cls, data_string, format)
#     650 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     651     """Return a class cls instance based on the input string and the
#     652     format string."""
# --> 653     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     654     tzname, gmtoff = tt[-2:]
#     655     args = tt[:6] + (fraction,)
#
# File C:\Anaconda\envs\tf_env\Lib\_strptime.py:435, in _strptime(data_string, format)
#     432     raise ValueError("time data %r does not match format %r" %
#     433                      (data_string, format))
#     434 if len(data_string) != found.end():
# --> 435     raise ValueError("unconverted data remains: %s" %
#     436                       data_string[found.end():])
#     438 iso_year = year = None
#     439 month = day = 1
#
# ValueError: unconverted data remains: 21

# %%
format = '%d-%m-%Y' 
datetime_dt = datetime.datetime.strptime(datetime_str, format)
print(datetime_dt)
# Out:
# 2021-08-07 00:00:00

# %%
print(type(datetime_dt))
# Out:
# <class 'datetime.datetime'>

# %%
## Quiz 2

# %%
## FinanceDataReader 패키지를 사용하여 미코바이오메드 종목의 2020년 1월 8일부터 2021년 7월 1일까지의 데이터를 로드 및 출력해보세요.

# %%
df = dfr.DataReader('214610','2020')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df = dfr.DataReader('214610','2020')
#
# NameError: name 'dfr' is not defined

# %%
df = fdr.DataReader('214610','2020')

# %%
df.head(10)
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2020-01-02  36617  38033  36617  36951     115  0.009094
# 2020-01-03  36951  36951  36951  36951       0  0.000000
# 2020-01-06  38033  38033  36951  36951      18  0.000000
# 2020-01-07  36951  36951  36951  36951       0  0.000000
# 2020-01-08  36951  36951  35858  36951      14  0.000000
# 2020-01-09  36951  36951  34765  36951       0  0.000000
# 2020-01-10  36951  39116  36399  36951      60  0.000000
# 2020-01-13  36930  38023  36129  36129     868 -0.022246
# 2020-01-14  36128  36951  34765  36899     656  0.021313
# 2020-01-15  36930  36930  34765  36400    1411 -0.013523

# %%
df = fdr.DataReader('214610', '2020-01-08', '2021-07-01')

# %%
df
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2020-01-08   36951   36951   35858   36951      14  0.000000
# 2020-01-09   36951   36951   34765   36951       0  0.000000
# 2020-01-10   36951   39116   36399   36951      60  0.000000
# 2020-01-13   36930   38023   36129   36129     868 -0.022246
# 2020-01-14   36128   36951   34765   36899     656  0.021313
# ...            ...     ...     ...     ...     ...       ...
# 2021-06-25  120296  121409  117693  118818   27566  0.003166
# 2021-06-28  119557  121409  118058  119557   27727  0.006220
# 2021-06-29  121024  149617  114352  114727  541451 -0.040399
# 2021-06-30  114727  117319  112864  115102   53580  0.003269
# 2021-07-01  116205  123626  115830  120296   87041  0.045125
#
# [368 rows x 6 columns]

# %%
## 파이썬 패키지 Numpy를 사용하여 2021년 3월 1일부터 2021년 7월 1일 사이의 모든 일자를 출력하세요. 단, 7월 1일도 포함해야 합니다.

# %%
import pandas as pd

# %%
pd.date_range('2021-03','2021-07')
# Out:
# DatetimeIndex(['2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04',
#                '2021-03-05', '2021-03-06', '2021-03-07', '2021-03-08',
#                '2021-03-09', '2021-03-10',
#                ...
#                '2021-06-22', '2021-06-23', '2021-06-24', '2021-06-25',
#                '2021-06-26', '2021-06-27', '2021-06-28', '2021-06-29',
#                '2021-06-30', '2021-07-01'],
#               dtype='datetime64[us]', length=123, freq='D')

# %%
import numpy as np

# %%
np.arange('2021-03-01', '2021-07-01', dtype = 'datetime64[D]')
# Out:
# array(['2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04',
#        '2021-03-05', '2021-03-06', '2021-03-07', '2021-03-08',
#        '2021-03-09', '2021-03-10', '2021-03-11', '2021-03-12',
#        '2021-03-13', '2021-03-14', '2021-03-15', '2021-03-16',
#        '2021-03-17', '2021-03-18', '2021-03-19', '2021-03-20',
#        '2021-03-21', '2021-03-22', '2021-03-23', '2021-03-24',
#        '2021-03-25', '2021-03-26', '2021-03-27', '2021-03-28',
#        '2021-03-29', '2021-03-30', '2021-03-31', '2021-04-01',
#        '2021-04-02', '2021-04-03', '2021-04-04', '2021-04-05',
