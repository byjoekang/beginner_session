# %%
2 + 5
# Out:
# 7

# %%
,,,
아오
,,,

2 + 5
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:3: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:3: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\황건호\AppData\Local\Temp\ipykernel_5180\4128286216.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   ("")("")("")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ("")("")("")
#       2 아오
#       3 ("")("")("")
#       4
#
# TypeError: 'str' object is not callable

# %%
'''
아오
'''

2 + 5
# Out:
# 7

# %%
a = 3
print(a)
# Out:
# 3

# %%
a = 3
b = 5
c = a + b
print(c)
# Out:
# 8

# %%
print(a+b)
# Out:
# 8

# %%
a = 3
b = 2.5

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
a=7
b = 2

print(a+b)
# Out:
# 9

# %%
print(a-b)
# Out:
# 5

# %%
print(a/b)
# Out:
# 3.5

# %%
print(a%b)
# Out:
# 1

# %%
print(a**b)
# Out:
# 49

# %%
x = True
y = False

# %%
type(x)
# Out:
# bool

# %%
True = 1
# Out:
#   Cell In[18], line 1
#     True = 1
#     ^
# SyntaxError: cannot assign to True

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
sr = pd.Series([17000, 18000, 1000, 5000],
               index=["피자", "치킨", "콜라", "맥주"])
print('시리즈 출력 :')
print('-'*15)
print(sr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sr = pd.Series([17000, 18000, 1000, 5000],
#       2                index=["피자", "치킨", "콜라", "맥주"])
#       3 print('시리즈 출력 :')
#       4 print('-'*15)
#
# NameError: name 'pd' is not defined
